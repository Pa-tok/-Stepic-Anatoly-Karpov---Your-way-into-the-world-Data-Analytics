# %%
import pandas as pd
import numpy as np
import seaborn as sns
from io import BytesIO
import requests
import matplotlib.pyplot as plt
from pathlib import Path

# %%
# Вывод данных из csv во всю ширину окна
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %% [markdown]
# ## Убираем индекс

# %%
df0 = pd.DataFrame({"ID": ["A", "B", "A", "C", "A", "A", "C", "B"], "value": [1, 2, 4, 3, 6, 7, 3, 4]})
print('Первые 5 строк:\n', df0.head())
print('Количество строк и колонок:\n', df0.shape)
print('Типы данных:\n', df0.dtypes)

df_group1 = df0.set_index("ID") # сделаем колонку ID индексом
print ('делаем колонку ID индексом:\n', df_group1)

# plt.figure(figsize=(12, 8)) # Изменяем размер


df_group2 = df0.groupby("ID", as_index=False).sum() #  Фиксация строки
# print (df_group2)

# df_group1 = df0.groupby("ID").sum().reset_index() #  Убираем индекс
# Out:
# Первые 5 строк:
#    ID  value
# 0  A      1
# 1  B      2
# 2  A      4
# 3  C      3
# 4  A      6
# Количество строк и колонок:
#  (8, 2)
# Типы данных:
#  ID       object
# value     int64
# dtype: object
# делаем колонку ID индексом:
#      value
# ID
# A       1
# B       2
# A       4
# C       3
# A       6
# A       7
# C       3
# B       4

# %% [markdown]
# 1) ⭐️Задание со звёздочкой!⭐️
# Загрузите данные из Google Sheets, которые находятся в папке (table - Лист1) при помощи библиотеки requests. Посчитайте процент мужчин среди всех посетителей сайта, округлите ответ до целых.
# Воспользуйтесь этим кодом, чтобы перевести данные из реквеста в пандас
#
# from io import BytesIO
# import requests
#
# req = requests.get(your_link)
# data = req.content
#
# df = pd.read_csv(BytesIO(data))

# %%
from io import BytesIO
import requests
# url = 'e:\!Data-scientist\!!LessonPre\[Stepic] Анатолий Карпов - Твой путь в мир Data Analytics\Data\\table - Лист1.csv'
# your_link = 'https://docs.google.com/spreadsheets/d/1lWg5Z4NX0wO_o-KdhfRd-eBr7y2jvzl_EFPSrbyolYI/edit#gid=0'
your_link = 'https://docs.google.com/spreadsheets/d/1UhwZEdVZSzns3IApkZQTrbb7zdM5LYP8C9ZRlCSzSrI/edit#gid=0'
req = requests.get(your_link)
req
# # <Response [200]>
type(req)
# requests.models.Response
req = requests.get(your_link)
data = req.content
# df = pd.read_csv(BytesIO(data))
df = pd.read_csv(BytesIO(data), on_bad_lines='skip')
df
# Out:
# <Response [200]>

# %%
# Out:
# requests.models.Response

# %%
# Out:
#                                                                                                                                                          <!DOCTYPE html><html lang="ru-RU"><head><script nonce="Ek2Zse1uZYN9Ax0znhxS5w">var DOCS_timing={}; DOCS_timing['pls']=new Date().getTime();</script><meta property="og:title" content="b Karpov"><meta property="og:type" content="article"><meta property="og:site_name" content="Google Docs"><meta property="og:url" content="https://docs.google.com/spreadsheets/d/1UhwZEdVZSzns3IApkZQTrbb7zdM5LYP8C9ZRlCSzSrI/edit?usp=embed_facebook"><meta property="og:image" content="https://lh5.googleusercontent.com/ETTuaWraQqnEb8dolm0zbCVwO85BjRzV-raSpq53FxG1JDAIMwAUzcOR3_gj7jRb9vWHaM53L5I-tQ=w1200-h630-p"><meta property="og:image:width" content="1200"><meta property="og:image:height" content="630"><meta property="og:description" content="Лист1
# date                                               browser                                            user_type                                                                                       users
# 2020-06-14                                         Google_Chrome                                      People                                                                                            139
#                                                    Chrome_Mobile                                      People                                                                                             35
#                                                    Google_Chrome                                      Robots                                                                                             28
#                                                    Yandex_Browser                                     People                                                                                             22
#                                                    Firefox                                            People                                                                                             15
#                                                    Safari                                             People                                                                                             13
#                                                    Firefox                                            Robots                                                                                              8
# try{                                               NaN                                                NaN                                                                                               NaN
# _.ia=function(){return _.p("Safari")&&!(_.ha()|... NaN                                                NaN                                                                                               NaN
# _.Xa=function(a){var b="undefined"!=typeof Symb... bb={};try{bb.__proto__=ab;$a=bb.a;break a}catch... b){a.__proto__=b;if(a.__proto__!==b)throw new T...                                                NaN
# var fb=function(a                                  b){return Object.prototype.hasOwnProperty.call(a   b)};                                                                                              NaN
# fb(l                                               f)&&fb(l[f]                                        this.j)?delete l[f][this.j]:!1};return h});                                                       NaN
# /*                                                 NaN                                                NaN                                                                                               NaN
#  Copyright The Closure Library Authors.            NaN                                                NaN                                                                                               NaN
#  SPDX-License-Identifier: Apache-2.0               NaN                                                NaN                                                                                               NaN
# */                                                 NaN                                                NaN                                                                                               NaN
# _.B(_.aa                                           Error);_.aa.prototype.name="CustomError";          NaN                                                                                               NaN
# _.sb=String.prototype.trim?function(a){return a... NaN                                                NaN                                                                                               NaN
# _.Ab=function(a){_.Ab[" "](a);return a};_.Ab[" ... NaN                                                NaN                                                                                               NaN
# var Ob                                             Pb                                                 Ub;_.Bb=_.ca();_.C=_.ea();_.Cb=_.p("Edge");_.Db...                                                NaN
# a:{var Qb=""                                       Rb=function(){var a=_.ba();if(_.Eb)return/rv:([... 10)||void 0}else Ub=void 0;_.Wb=Ub;                                                               NaN
# _.Xb=_.fa();_.Yb=ka()||_.p("iPod");_.Zb=_.p("iP... NaN                                                NaN                                                                                               NaN
# var oa;oa="undefined"!==typeof Uint8Array;_.Ka={}; NaN                                                NaN                                                                                               NaN
# _.fc="function"===typeof Uint8Array.prototype.s... NaN                                                NaN                                                                                               NaN
# _.gc="undefined"!==typeof TextDecoder;_.hc="und... NaN                                                NaN                                                                                               NaN
# var ic;_.Ca=function(a                             b){if(b!==_.Ka)throw Error("t");this.Aa=a;if(nu... _.Ka))};_.Ca.prototype.bc=function(){return nul...                                                NaN
# var qa="function"===typeof Symbol&&"symbol"===t... NaN                                                NaN                                                                                               NaN
# var nc;_.Ga={};_.kc=Object.freeze(_.va([]));_.l... NaN                                                NaN                                                                                               NaN
# ;_.zc=Symbol();_.Ac=Symbol();_.Bc=Symbol();_.Cc... NaN                                                NaN                                                                                               NaN
# if(nc){var Dc={};Object.defineProperties(_.G       (Dc[Symbol.hasInstance]=Aa(Object[Symbol.hasIns... Dc))}                                                                                             NaN
# ;var Ec=function(a){_.G.call(this                  a)};_.w(Ec                                         _.G);                                                                                             NaN
# var Gc=function(a){_.G.call(this                   a)};_.w(Gc                                         _.G);                                                                                             NaN
# _.Ic=function(a){_.G.call(this                     a)};_.w(_.Ic                                       _.G);                                                                                             NaN
# _.H=function(){this.Mb=this.Mb;this.Ma=this.Ma}... this.R())};_.H.prototype.R=function(){if(this.M... NaN                                                                                               NaN
# var Kc=function(a){_.H.call(this);this.A=a;this... _.H);Kc.prototype.F=function(a                     b){this.j=b;this.C=a;b.preventDefault?b.prevent...                                                NaN
# _.Lc=function(a){_.G.call(this                     a)};_.w(_.Lc                                       _.G);                                                                                             NaN
# _.Mc=function(a){_.G.call(this                     a)};_.w(_.Mc                                       _.G);                                                                                             NaN
# _.Nc=function(){this.data={}};_.Nc.prototype.o=... this.data)};_.Nc.prototype.j=function(a){var b=[]  c;for(c in this.data)b.push(encodeURIComponent(...                                               a)};
# var Pa="constructor hasOwnProperty isPrototypeO... NaN                                                NaN                                                                                               NaN
# var Qc;_.Rc=function(){void 0===Qc&&(Qc=_.rb("o... NaN                                                NaN                                                                                               NaN
# _.Tc=function(a                                    b){this.j=b===_.Sc?a:""};_.Tc.prototype.toStrin... NaN                                                                                               NaN
# _.bd=function(a){if(a instanceof _.Xc)return a;... )                                                  a=a.match(Zc)?_.ad(a):null);return a};_.cd=func...         Wc)};_.dd=_.ad("about:invalid#zClosurez");
# _.kd=RegExp("\\b(calc|cubic-bezier|fit-content|...  ]+\\)"                                            g);                                                                                               NaN
# var ld;ld={};_.md=function(a                       b){this.j=b===ld?a:"";this.Pb=!0};_.md.prototyp... ld)};_.pd=new _.md(_.n.trustedTypes&&_.n.truste...                             ld);_.qd=_.od("<br>");
# _.td=function(a){a=(a||_.n).document;return a.q... link[rel="stylesheet"][nonce]'))&&(a=a.nonce||a... NaN                                                                                               NaN
# _.ud=RegExp("^\\s{3                                4}at(?: (?:(.*?)\\.)?((?:new )?(?:[a-zA-Z_$][\\... NaN                                                                                               NaN
# var wd                                             zd                                                 yd;_.xd=function(a){var b=window.google&&window...  c=yd;b.onerror=b.onload=b.onabort=function(){c...
# _.Ad=function(a){_.G.call(this                     a)};_.w(_.Ad                                       _.G);                                                                                             NaN
# _.Bd=function(a){var b="Ic";if(a.Ic&&a.hasOwnPr... NaN                                                NaN                                                                                               NaN
# var Rd=function(a){_.G.call(this                   a)};_.w(Rd                                         _.G);                                                                                             NaN
# _.I=function(){this.B=new _.Wd;this.j=new _.Wd;... NaN                                                NaN                                                                                               NaN
# var ce;window.gbar_&&window.gbar_.CONFIG?ce=win... NaN                                                NaN                                                                                               NaN
# ...
# }catch(e){_._DumpException(e)}                     NaN                                                NaN                                                                                               NaN
# try{                                               NaN                                                NaN                                                                                               NaN
# }catch(e){_._DumpException(e)}                     NaN                                                NaN                                                                                               NaN
# try{                                               NaN                                                NaN                                                                                               NaN
# /*                                                 NaN                                                NaN                                                                                               NaN
#  SPDX-License-Identifier: Apache-2.0               NaN                                                NaN                                                                                               NaN
# */                                                 NaN                                                NaN                                                                                               NaN
# var Mj;try{new URL("s://g")                        Mj=!0}catch(a){Mj=!1}_.Nj=Mj;                      NaN                                                                                               NaN
# }catch(e){_._DumpException(e)}                     NaN                                                NaN                                                                                               NaN
# try{                                               NaN                                                NaN                                                                                               NaN
# /*                                                 NaN                                                NaN                                                                                               NaN
#  SPDX-License-Identifier: Apache-2.0               NaN                                                NaN                                                                                               NaN
# */                                                 NaN                                                NaN                                                                                               NaN
# }catch(e){_._DumpException(e)}                     NaN                                                NaN                                                                                               NaN
# try{                                               NaN                                                NaN                                                                                               NaN
# }catch(e){_._DumpException(e)}                     NaN                                                NaN                                                                                               NaN
# })(this.gbar_);                                    NaN                                                NaN                                                                                               NaN
# // Google Inc.                                     NaN                                                NaN                                                                                               NaN

# %%
from io import BytesIO
import requests
r = requests.get('https://docs.google.com/spreadsheets/d/e/2PACX-1vQWMsvBTVio9C7IOOxfFO9C15BRHyME-_ENHqBodDOjuiHwk9fCuF5hUVmDs497PZOqPYK3exdSikOK/pub?gid=1006633900&single=true&output=csv')
data = r.content
df = pd.read_csv(BytesIO(data))
df

# %% [markdown]
# 2) Скачайте файл с данными посещаемости сайта Яндекс.Метрика (karpov_courses_test.csv). При помощи функции np.where создайте серию, в которую будет записываться 1, если посещения были сделаны роботами с браузера, содержащего Chrome в названии и 0, в других случаях. Поместите получившуюся серию в переменную chrome_robots
# Может понадобиться:
# str.contains()

# %% [markdown]
# 3) ⭐️Задание со звёздочкой!⭐️
# У вас есть датасет sample_ads.csv с данными о кликах и показах по объявлению, в этом датасете есть пропуски. Вычислите количество строк без пропусков в колонке click_type. Запишите ответ в переменную not_nan_count
#
#     ad_id - id объявления
#     user_id - id пользователя
#     click_type - тип клика (клик по заголовку объявления, клик по центру)

# %% [markdown]
# 4) ⭐️Задание со звёздочкой!⭐️
# В списке lst находятся различные элементы. Создайте списк new_list и сделайте следующее:
# - при помощи конструкции try except и цикла попробуйте преобразовать каждое значение в листе в int
# - если это получилось - добавьте преобразованное значение  в список new_list

# %% [markdown]
# 5) ⭐️Задание со звёздочкой!⭐️
# А теперь попробуем воспользоваться знаниями использования Telegram API. Отправьте себе в личку любое послание, а в ответ к этому шагу напишите ник бота, от имени которого будете отправлять сообщения.
